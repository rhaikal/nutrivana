# %%
import pandas as pd

# %%
pd.read_excel("data/wfh_boys_2-to-5-years_zscores.xlsx")
# Out:
#      Height       L        M        S  SD3neg  SD2neg  SD1neg   SD0   SD1  \
# 0      65.0 -0.3521   7.4327  0.08217     5.9     6.3     6.9   7.4   8.1
# 1      65.5 -0.3521   7.5504  0.08214     6.0     6.4     7.0   7.6   8.2
# 2      66.0 -0.3521   7.6673  0.08212     6.1     6.5     7.1   7.7   8.3
# 3      66.5 -0.3521   7.7834  0.08212     6.1     6.6     7.2   7.8   8.5
# 4      67.0 -0.3521   7.8986  0.08213     6.2     6.7     7.3   7.9   8.6
# ..      ...     ...      ...      ...     ...     ...     ...   ...   ...
# 106   118.0 -0.3521  21.5611  0.09300    16.5    18.0    19.7  21.6  23.7
# 107   118.5 -0.3521  21.7588  0.09331    16.7    18.2    19.9  21.8  23.9
# 108   119.0 -0.3521  21.9568  0.09362    16.8    18.3    20.0  22.0  24.1
# 109   119.5 -0.3521  22.1549  0.09393    16.9    18.5    20.2  22.2  24.4
# 110   120.0 -0.3521  22.3530  0.09424    17.1    18.6    20.4  22.4  24.6
#
#       SD2   SD3
# 0     8.8   9.6
# 1     8.9   9.8
# 2     9.1   9.9
# ...

# %%
len("Berisiko gizi lebih (possible risk of overweight)")
# Out:
# 49

# %%
18 * 30
# Out:
# 540
